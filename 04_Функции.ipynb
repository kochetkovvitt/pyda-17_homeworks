# %% [markdown]
# ## Домашнее задание к лекции "Функции"

# %%
# перечень всех документов
documents = [
 {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
 {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
 {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]
# перечень полок, на которых хранятся документы
# если документ есть в documents, то он обязательно должен быть и в directories
directories = {
 '1': ['2207 876234', '11-2'],
 '2': ['10006'],
 '3': []
}

# %% [markdown]
# Общие требования к программе:
#
# - код должен быть грамотно декомпозирован (каждая функция отвечает за свою конкретную задачу, дублирующийся функционал переиспользуется, а его код не повторяется);
# - в коде отсутствуют глобальные переменные (за исключением documents и directories);
# - пользовательский ввод обрабатывается в цикле while до тех пор, пока пользователь явно не завершит программу (вводом команды "q").

# %%
def start():
    commands = {'p': show_document_owner, 's': show_document_shelf, 
                'l': show_document_list, 'ads': add_shelf, 
                'ds': delete_shelf, 'ad': add_document, 
                'd': delete_document, 'm': move_document}
    while True:
        command = input('Введите команду: ')
        
        if command == 'q':
            break
        elif command in commands:
            commands[command]()
        else:
            print('Доступные команды: p, s, l, ads, ds, ad, d, m')
            print('Для выхода введите команду q')

# %% [markdown]
# ### 1.1 Пользователь по команде "p" может узнать владельца документа по его номеру

# %%
# Примеры работы:
# -----------------------------
# Введите команду:
# p
# Введите номер документа:
# 10006
# Результат:
# Владелец документа: Аристарх Павлов
# -----------------------------
# Введите команду:
# p
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# %%
def show_document_owner():
    number = input('Введите номер документа: ')
    
    for document in documents:
        if document['number'] == number:
            print(f"Владелец документа: {document['name']}")
            return
    print('Документ не найден в базе')

# %%
start()
# Out:
# Введите команду: p
# Введите номер документа: 10006
# Владелец документа: Аристарх Павлов
# Введите команду: q

# %% [markdown]
# ### 1.2 Пользователь по команде "s" может по номеру документа узнать на какой полке он хранится

# %%
# Примеры работы:
# -----------------------------
# Введите команду:
# s
# Введите номер документа:
# 10006
# Результат:
# Документ хранится на полке: 2
# -----------------------------
# Введите команду:
# s
# Введите номер документа:
# 12345
# Результат:
# Документ не найден в базе

# %%
def show_document_shelf():
    number = input('Введите номер документа: ')
    
    for key, value in directories.items():
        if number in value:
            print(f"Документ хранится на полке: {key}")
            return
    print('Документ не найден в базе')

# %%
start()
# Out:
# Введите команду: s
# Введите номер документа: 10006
# Документ хранится на полке: 2
# Введите команду: q

# %% [markdown]
# ### 1.3 Пользователь по команде "l" может увидеть полную информацию по всем документам

# %%
# Пример работы:
# -----------------------------
# Введите команду:
# l
# Результат:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# %%
def show_document_list():
    for document in documents:
        shelf = ''
        for key, value in directories.items():
            if document['number'] in value:
                shelf = key
                break
        print(f"№: {document['number']}, тип: {document['type']}, "
              f"владелец: {document['name']}, полка хранения: {shelf}")

# %%
start()
# Out:
# Введите команду: l
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# Введите команду: q

# %% [markdown]
# ### 1.4 Пользователь по команде "ads" может добавить новую полку

# %%
# Примеры работы:
# -----------------------------
# Введите команду:
# ads
# Введите номер полки:
# 10
# Результат:
# Полка добавлена. Текущий перечень полок: 1, 2, 3, 10.
# -----------------------------
# Введите команду:
# ads
# Введите номер полки:
# 1
# Результат:
# Такая полка уже существует. Текущий перечень полок: 1, 2, 3.

# %%
def add_shelf():
    shelf = input('Введите номер полки: ')
    
    if shelf not in directories:
        directories[shelf] = []
        print(f"Полка добавлена. Текущий перечень полок: {', '.join(directories.keys())}.")
    else:
        print(f"Такая полка уже существует. Текущий перечень полок: {', '.join(directories.keys())}.")

# %%
start()
# Out:
# Введите команду: ads
# Введите номер полки: 10
# Полка добавлена. Текущий перечень полок: 1, 2, 3, 10.
# Введите команду: q

# %% [markdown]
# ### 1.5 Пользователь по команде "ds" может удалить существующую полку из данных (только если она пустая)

# %%
# Примеры работы:
# -----------------------------
# Введите команду:
# ds
# Введите номер полки:
# 3
# Результат:
# Полка удалена. Текущий перечень полок: 1, 2.
# -----------------------------
# Введите команду:
# ds
# Введите номер полки:
# 1
# Результат:
# На полке есть документы, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3.
# -----------------------------
# Введите команду:
# ds
# Введите номер полки:
# 4
# Результат:
# Такой полки не существует. Текущий перечень полок: 1, 2, 3.

# %%
def delete_shelf():
    shelf = input('Введите номер полки: ')
    
    if shelf not in directories:
        print(f"Такой полки не существует. Текущий перечень полок: {', '.join(directories.keys())}.")
    elif directories[shelf] != []:
        print("На полке есть документы, удалите их перед удалением полки. " 
             f"Текущий перечень полок: {', '.join(directories.keys())}.")
    else:
        directories.pop(shelf)
        print(f"Полка удалена. Текущий перечень полок: {', '.join(directories.keys())}.")

# %%
start()
# Out:
# Введите команду: ds
# Введите номер полки: 1
# На полке есть документы, удалите их перед удалением полки. Текущий перечень полок: 1, 2, 3, 10.
# Введите команду: q

# %% [markdown]
# ### 2.1 Пользователь по команде "ad" может добавить новый документ в данные

# %%
# Примеры работы:
# -----------------------------
# Введите команду:
# ad
# Введите номер документа:
# 42
# Введите тип документа:
# multipassport
# Введите владельца документа:
# R2D2
# Введите полку для хранения:
# 3
# Результат:
# Документ добавлен. Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# №: 42, тип: multipassport, владелец: R2D2, полка хранения: 3
# -----------------------------
# Введите команду:
# ad
# Введите номер документа:
# 42
# Введите тип документа:
# multipassport
# Введите владельца документа:
# R2D2
# Введите полку для хранения:
# 4
# Результат:
# Такой полки не существует. Добавьте полку командой ads. 
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# %%
def add_document():
    number = input('Введите номер документа: ')
    d_type = input('Введите тип документа: ')
    name = input('Введите владельца документа: ')
    shelf = input('Введите полку для хранения: ')
    
    if shelf not in directories:
        print('Такой полки не существует. Добавьте полку командой ads.')
        print('Текущий список документов:')
        show_document_list()
    else:
        documents.append({'type': d_type, 'number': number, 'name': name})
        directories[shelf].append(number)
        print('Документ добавлен. Текущий список документов:')
        show_document_list()

# %%
start()
# Out:
# Введите команду: ad
# Введите номер документа: 42
# Введите тип документа: multipassport
# Введите владельца документа: R2D2
# Введите полку для хранения: 3
# Документ добавлен. Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# №: 42, тип: multipassport, владелец: R2D2, полка хранения: 3
# Введите команду: q

# %% [markdown]
# ### 2.2 Пользователь по команде "d" может удалить документ из данных

# %%
# Примеры работы:
# -----------------------------
# Введите команду:
# d
# Введите номер документа:
# 10006
# Результат:
# Документ удален. 
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# -----------------------------
# Введите команду:
# d
# Введите номер документа:
# 123456
# Результат:
# Документ не найден в базе. 
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# %%
def delete_document():
    number = input('Введите номер документа: ')
    
    for index, document in enumerate(documents):
        if document['number'] == number:
            documents.pop(index)
            print('Документ удален.')
            print('Текущий список документов:')
            show_document_list()
            return
    print('Документ не найден в базе.')
    print('Текущий список документов:')
    show_document_list()

# %%
start()
# Out:
# Введите команду: d
# Введите номер документа: 10006
# Документ удален.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 42, тип: multipassport, владелец: R2D2, полка хранения: 3
# Введите команду: q

# %% [markdown]
# ### 2.3 Пользователь по команде "m" может переместить документ с полки на полку

# %%
# Примеры работы:
# -----------------------------
# Введите команду:
# m
# Введите номер документа:
# 11-2
# Введите номер полки:
# 3
# Результат:
# Документ перемещен. 
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 3
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2
# -----------------------------
# Введите команду:
# m
# Введите номер документа:
# 11-2
# Введите номер полки:
# 10
# Результат:
# Такой полки не существует. Текущий перечень полок: 1, 2, 3.
# -----------------------------
# Введите команду:
# m
# Введите номер документа:
# 42
# Введите номер полки:
# 2
# Результат:
# Документ не найден в базе. 
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 10006, тип: insurance, владелец: Аристарх Павлов, полка хранения: 2

# %%
def move_document():
    number = input('Введите номер документа: ')
    shelf = input('Введите полку для хранения: ')
    
    if shelf not in directories:
        print(f"Такой полки не существует. Текущий перечень полок: {', '.join(directories.keys())}.")
        return
              
    for key, value in directories.items():
        if number in value:
            if shelf == key:
                print(f'Документ уже находится на полке {shelf}.')
            else:
                value.remove(number)
                directories[shelf].append(number)
                print('Документ перемещен.')
                print('Текущий список документов:')
                show_document_list()
            return
    
    print('Документ не найден в базе.')
    print('Текущий список документов:')
    show_document_list()

# %%
start()
# Out:
# Введите команду: m
# Введите номер документа: 42
# Введите полку для хранения: 1
# Документ перемещен.
# Текущий список документов:
# №: 2207 876234, тип: passport, владелец: Василий Гупкин, полка хранения: 1
# №: 11-2, тип: invoice, владелец: Геннадий Покемонов, полка хранения: 1
# №: 42, тип: multipassport, владелец: R2D2, полка хранения: 1
# Введите команду: q
