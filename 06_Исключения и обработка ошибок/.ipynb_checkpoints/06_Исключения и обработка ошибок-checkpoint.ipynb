# %% [markdown]
# ## Домашнее задание к лекции «Исключения и обработка ошибок»

# %%
from datetime import datetime
from datetime import timedelta
# https://docs.python.org/3/library/datetime.html

# %% [markdown]
# ### Задание 1
# Печатные газеты использовали свой формат дат для каждого выпуска.
# Для каждой газеты из списка напишите формат указанной даты для перевода в объект datetime:
# - The Moscow Times - Wednesday, October 2, 2002
# - The Guardian - Friday, 11.10.13
# - Daily News - Thursday, 18 August 1977

# %%
the_moskow_times_dt = datetime.strptime('Wednesday, October 2, 2002', '%A, %B %d, %Y')
the_moskow_times_dt
# Out:
# datetime.datetime(2002, 10, 2, 0, 0)

# %%
the_guardian_dt = datetime.strptime('Friday, 11.10.13', '%A, %d.%m.%y')
the_guardian_dt
# Out:
# datetime.datetime(2013, 10, 11, 0, 0)

# %%
daily_news_dt = datetime.strptime('Thursday, 18 August 1977', '%A, %d %B %Y')
daily_news_dt
# Out:
# datetime.datetime(1977, 8, 18, 0, 0)

# %% [markdown]
# ### Задание 2
# Дан поток дат в формате YYYY-MM-DD, в которых встречаются некорректные значения:
# stream = [‘2018-04-02’, ‘2018-02-29’, ‘2018-19-02’]
#
# Напишите функцию, которая проверяет эти даты на корректность.
# Т. е. для каждой даты возвращает True (дата корректна) или False (некорректная дата).

# %%
def is_date_correct(date):
    try:
        datetime.strptime(date, '%Y-%m-%d')
    except:
        return False
    return True

stream = ['2018-04-02', '2018-02-29', '2018-19-02']
[is_date_correct(date) for date in stream]
# Out:
# [True, False, False]

# %% [markdown]
# ### Задание 3
# Напишите функцию date_range, которая возвращает список дат за период от start_date до end_date.
# Даты должны вводиться в формате YYYY-MM-DD.
# В случае неверного формата или при start_date > end_date должен возвращаться пустой список.

# %%
def date_range(start_date, end_date):
    try:
        start_dt = datetime.strptime(start_date, '%Y-%m-%d')
        end_dt = datetime.strptime(end_date, '%Y-%m-%d')
    except:
        return []
    
    if start_dt > end_dt:
        return []
    
    res = []
    current_dt = start_dt
    while current_dt <= end_dt:
        res.append(current_dt.strftime('%Y-%m-%d'))
        current_dt += timedelta(days=1)
    return res

# %%
print(date_range('2018-19-01', '2018-19-04'))
print(date_range('2018-01-31', '2018-01-29'))
print(date_range('2018-01-31', '2018-01-31'))
print(date_range('2018-01-31', '2018-02-02'))
# Out:
# []
# []
# ['2018-01-31']
# ['2018-01-31', '2018-02-01', '2018-02-02']

# %% [markdown]
# ### Задание 4
# Ваш коллега прислал код функции:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# При однократном вызове этой функции все работает корректно:
# delete_and_return_last_user(1)
# ‘A101’
#
# Однако, при повторном вызове получается ошибка IndexError: list index out of range:

# %%
DEFAULT_USER_COUNT = 3

def delete_and_return_last_user(region, default_list=['A100', 'A101', 'A102']):

    element_to_delete = default_list[-1]
    print('element_to_delete =', element_to_delete)

    default_list.remove(element_to_delete)
    print('default_list =', default_list)

    print('DEFAULT_USER_COUNT-2 =', DEFAULT_USER_COUNT-2)

    return default_list[DEFAULT_USER_COUNT-2]

# %%
delete_and_return_last_user(1)
# Out:
# element_to_delete = A102
# default_list = ['A100', 'A101']
# DEFAULT_USER_COUNT-2 = 1
# 'A101'

# %%
delete_and_return_last_user(1)
# Out:
# element_to_delete = A101
# default_list = ['A100']
# DEFAULT_USER_COUNT-2 = 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-bfb6c4f8c48e> in <module>
# ----> 1 delete_and_return_last_user(1)
#
# <ipython-input-8-7e9c7b3c0c21> in delete_and_return_last_user(region, default_list)
#      11     print('DEFAULT_USER_COUNT-2 =', DEFAULT_USER_COUNT-2)
#      12
# ---> 13     return default_list[DEFAULT_USER_COUNT-2]
#
# IndexError: list index out of range

# %% [markdown]
# Задание:
#
# #### 1. Что значит ошибка list index out of range?
# Это значит что была попытка обратиться к несуществующему индексу в списке.
#
# #### 2. Почему при первом запуске функция работает корректно, а при втором - нет?
# В первом случае у нас есть параметр по умолчанию как список из 3-х элементов.
# Вычисляется и удаляется последний элемент этого списка. И функция возвращает второй элемент списка (с индексом 1).
#
# А при втором запуске, поскольку значения параметров по умолчанию создаются при определении функции, а не каждый раз, когда она вызывается в коде программы (https://docs.python.org/3/reference/compound_stmts.html#function-definitions), выходит что в параметре default_list осталось два элемента.
# После удаления последнего (второго) остается один элемент. И функция при попытке обратиться ко второму элементу в списке с одним элементом получает IndexError.
